# %%
# !pip install langchain==0.2.7 langchain_community==0.2.7 langchain_openai==0.1.15 langchain-chroma==0.1.1 langchainhub==0.1.20
# Out:
# Collecting langchain==0.2.7
#   Downloading langchain-0.2.7-py3-none-any.whl.metadata (6.9 kB)
# Collecting langchain_community==0.2.7
#   Downloading langchain_community-0.2.7-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain_openai==0.1.15
#   Downloading langchain_openai-0.1.15-py3-none-any.whl.metadata (2.5 kB)
# Collecting langchain-chroma==0.1.1
#   Downloading langchain_chroma-0.1.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting langchainhub==0.1.20
#   Downloading langchainhub-0.1.20-py3-none-any.whl.metadata (659 bytes)
# Requirement already satisfied: PyYAML>=5.3 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.12 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (0.2.33)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (0.1.99)
# Requirement already satisfied: numpy<2,>=1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain==0.2.7) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain_community==0.2.7) (0.6.7)
# Requirement already satisfied: openai<2.0.0,>=1.32.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain_openai==0.1.15) (1.41.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain_openai==0.1.15) (0.7.0)
# Collecting chromadb<0.6.0,>=0.4.0 (from langchain-chroma==0.1.1)
#   Downloading chromadb-0.5.16-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: fastapi<1,>=0.95.2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain-chroma==0.1.1) (0.112.1)
# Requirement already satisfied: packaging<25,>=23.2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchainhub==0.1.20) (24.1)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub==0.1.20)
#   Downloading types_requests-2.32.0.20241016-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.7) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.7) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.7) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.7) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.7) (1.9.4)
# Collecting build>=1.0.3 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-win_amd64.whl.metadata (262 bytes)
# Requirement already satisfied: uvicorn>=0.18.3 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.30.6)
# Collecting posthog>=2.4.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading posthog-3.7.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading onnxruntime-1.19.2-cp311-cp311-win_amd64.whl.metadata (4.7 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation_fastapi-0.48b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_sdk-1.27.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/67.3 kB ? eta -:--:--
#      ---------------------------------- --- 61.4/67.3 kB 812.7 kB/s eta 0:00:01
#      -------------------------------------- 67.3/67.3 kB 731.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.66.4)
# Requirement already satisfied: overrides>=7.3.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (7.7.0)
# Requirement already satisfied: importlib-resources in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (6.4.3)
# Collecting grpcio>=1.58.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading grpcio-1.67.1-cp311-cp311-win_amd64.whl.metadata (4.0 kB)
# Requirement already satisfied: bcrypt>=4.0.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.1.3)
# Requirement already satisfied: typer>=0.9.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.12.4)
# Collecting kubernetes>=28.1.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting mmh3>=4.0.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading mmh3-5.0.1-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.27.0)
# Requirement already satisfied: rich>=10.11.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (13.7.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.7) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.7) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1) (0.38.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from langchain-core<0.3.0,>=0.2.12->langchain==0.2.7) (1.33)
# Requirement already satisfied: anyio<5,>=3.5.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain_openai==0.1.15) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain_openai==0.1.15) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain_openai==0.1.15) (0.5.0)
# Requirement already satisfied: sniffio in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from openai<2.0.0,>=1.32.0->langchain_openai==0.1.15) (1.3.1)
# Requirement already satisfied: annotated-types>=0.4.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from pydantic<3,>=1->langchain==0.2.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from pydantic<3,>=1->langchain==0.2.7) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from requests<3,>=2->langchain==0.2.7) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from requests<3,>=2->langchain==0.2.7) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from requests<3,>=2->langchain==0.2.7) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from requests<3,>=2->langchain==0.2.7) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.7) (3.0.3)
# Requirement already satisfied: regex>=2022.1.18 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai==0.1.15) (2024.5.15)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.4.6)
# Requirement already satisfied: httpcore==1.* in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.12->langchain==0.2.7) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: sympy in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (8.0.0)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.27.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.27.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_proto-1.27.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading protobuf-4.25.5-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting opentelemetry-instrumentation-asgi==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation_asgi-0.48b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation-0.48b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_semantic_conventions-0.48b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-util-http==0.48b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_util_http-0.48b0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: setuptools>=16.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (69.5.1)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from rich>=10.11.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from rich>=10.11.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community==0.2.7) (1.0.0)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading httptools-0.6.4-cp311-cp311-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading watchfiles-0.24.0-cp311-none-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: websockets>=10.4 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (5.4.0)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: filelock in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.19.2)
# Requirement already satisfied: mdurl~=0.1 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.1.2)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in f:\programe_install\anaconda3\envs\flaskprojectnew\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading langchain-0.2.7-py3-none-any.whl (983 kB)
#    ---------------------------------------- 0.0/983.6 kB ? eta -:--:--
#    - -------------------------------------- 30.7/983.6 kB ? eta -:--:--
#    -- ------------------------------------ 71.7/983.6 kB 991.0 kB/s eta 0:00:01
#    ------- -------------------------------- 184.3/983.6 kB 1.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 256.0/983.6 kB 1.6 MB/s eta 0:00:01
#    ------------ --------------------------- 317.4/983.6 kB 1.5 MB/s eta 0:00:01
#    -------------- ------------------------- 368.6/983.6 kB 1.4 MB/s eta 0:00:01
#    --------------- ------------------------ 389.1/983.6 kB 1.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 419.8/983.6 kB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 553.0/983.6 kB 1.4 MB/s eta 0:00:01
#    ------------------------ --------------- 614.4/983.6 kB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 675.8/983.6 kB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 675.8/983.6 kB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 798.7/983.6 kB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ----
#    ---------------------------- --------- 204.8/277.5 kB 132.4 kB/s eta 0:00:01
#    ---------------------------- --------- 204.8/277.5 kB 132.4 kB/s eta 0:00:01
#    -------------------------------- ----- 235.5/277.5 kB 142.8 kB/s eta 0:00:01
#    ----------------------------------- -- 256.0/277.5 kB 149.8 kB/s eta 0:00:01
#    -------------------------------------  276.5/277.5 kB 157.7 kB/s eta 0:00:01
#    -------------------------------------- 277.5/277.5 kB 156.9 kB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#    -------- ------------------------------- 10.2/46.0 kB ? eta -:--:--
#    -------------------------- ------------- 30.7/46.0 kB 435.7 kB/s eta 0:00:01
#    ---------------------------------------- 46.0/46.0 kB 458.7 kB/s eta 0:00:00
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/86.8 kB ? eta -:--:--
#    -------------- ------------------------- 30.7/86.8 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 81.9/86.8 kB 762.6 kB/s eta 0:00:01
#    ---------------------------------------- 86.8/86.8 kB 702.3 kB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.5 kB ? eta -:--:--
#    ------ -------------------------------- 30.7/181.5 kB 660.6 kB/s eta 0:00:01
#    ------------- ------------------------- 61.4/181.5 kB 825.8 kB/s eta 0:00:01
#    ------------------- ------------------- 92.2/181.5 kB 751.6 kB/s eta 0:00:01
#    -------------------------------- ----- 153.6/181.5 kB 919.0 kB/s eta 0:00:01
#    -------------------------------------- 181.5/181.5 kB 995.9 kB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading wrapt-1.16.0-cp311-cp311-win_amd64.whl (37 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.1 kB ? eta -:--:--
#    ----------------------------- ---------- 61.4/83.1 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------  81.9/83.1 kB 919.0 kB/s eta 0:00:01
#    ---------------------------------------- 83.1/83.1 kB 775.5 kB/s eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/83.2 kB ? eta -:--:--
#    ---------------------------------------  81.9/83.2 kB ? eta -:--:--
#    ---------------------------------------- 83.2/83.2 kB 2.4 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53836 sha256=b5ab9b90172e6a2bb7eb01bae7fc07a2d8a4b6e7b64b07e92a24469165e8967e
#   Stored in directory: c:\users\18672\appdata\local\pip\cache\wheels\a3\01\bd\4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, flatbuffers, durationpy, wrapt, types-requests, pyreadline3, pyproject_hooks, pyasn1, protobuf, opentelemetry-util-http, oauthlib, mmh3, httptools, grpcio, chroma-hnswlib, backoff, asgiref, watchfiles, rsa, requests-oauthlib, pyasn1-modules, posthog, opentelemetry-proto, langchainhub, humanfriendly, googleapis-common-protos, deprecated, build, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, google-auth, coloredlogs, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-instrumentation-asgi, langchain_openai, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, langchain, langchain_community, chromadb, langchain-chroma
#   Attempting uninstall: langchain_openai
#     Found existing installation: langchain-openai 0.1.22
#     Uninstalling langchain-openai-0.1.22:
#       Successfully uninstalled langchain-openai-0.1.22
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.14
#     Uninstalling langchain-0.2.14:
#       Successfully uninstalled langchain-0.2.14
#   Attempting uninstall: langchain_community
#     Found existing installation: langchain-community 0.2.12
#     Uninstalling langchain-community-0.2.12:
#       Successfully uninstalled langchain-community-0.2.12
# Successfully installed asgiref-3.8.1 backoff-2.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.5.16 coloredlogs-15.0.1 deprecated-1.2.14 durationpy-0.9 flatbuffers-24.3.25 google-auth-2.35.0 googleapis-common-protos-1.65.0 grpcio-1.67.1 httptools-0.6.4 humanfriendly-10.0 kubernetes-31.0.0 langchain-0.2.7 langchain-chroma-0.1.1 langchain_community-0.2.7 langchain_openai-0.1.15 langchainhub-0.1.20 mmh3-5.0.1 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.19.2 opentelemetry-api-1.27.0 opentelemetry-exporter-otlp-proto-common-1.27.0 opentelemetry-exporter-otlp-proto-grpc-1.27.0 opentelemetry-instrumentation-0.48b0 opentelemetry-instrumentation-asgi-0.48b0 opentelemetry-instrumentation-fastapi-0.48b0 opentelemetry-proto-1.27.0 opentelemetry-sdk-1.27.0 opentelemetry-semantic-conventions-0.48b0 opentelemetry-util-http-0.48b0 posthog-3.7.0 protobuf-4.25.5 pyasn1-0.6.1 pyasn1-modules-0.4.1 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rsa-4.9 types-requests-2.32.0.20241016 watchfiles-0.24.0 wrapt-1.16.0

# %% [markdown]
# # 基于langchain实现私有知识库

# %% [markdown]
# ## 1. 依赖安装部署

# %% [raw]
# langchain==0.2.7
# langchain_community==0.2.7
# langchain_openai==0.1.15
# langchain-chroma==0.1.1
# langchainhub==0.1.20

# %% [markdown]
# ## 2. 依赖包导入

# %%
import bs4
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.chat_models import ChatZhipuAI
from zhipuai import ZhipuAI
import os
from dotenv import load_dotenv

# %% [markdown]
# ## 3. 初始化大模型

# %%
ZHIPUAI_API_KEY = "11f7603f3b47bb8f76abd6c0b7eb1017.rqh2hPOKFdfZLjOE"
WEB_URL = "https://github.com/WangShaoyu1/myBlogPaperMod/blob/master/content/posts/%E6%8E%A8%E8%8D%90%E4%B8%80%E4%B8%AA%E5%9C%A8%E4%BD%BF%E7%94%A8%E7%9A%84%E5%86%85%E7%BD%91%E7%A9%BF%E9%80%8F%E5%B7%A5%E5%85%B7cpolar.md"
ORI_WEB_URL = "https://lilianweng.github.io/posts/2023-06-23-agent/"

# %%
chat = ChatZhipuAI(
    model="glm-4",
    temperature=0.8,
    zhipuai_api_key=ZHIPUAI_API_KEY,
)

# %% [markdown]
# ## 4. 加载解析数据

# %%
loader = WebBaseLoader(
    web_paths=(WEB_URL,),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("Box-sc-g0xbh4-0")
        )
    ),
)

# %%
docs = loader.load()

# %% [markdown]
# ## 5. 数据切割

# %%
# 可视化观察切割效果的页面：https://chunkviz.up.railway.app/
text_splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=50)
splits = text_splitter.split_documents(docs)

# %% [markdown]
# ## 6. 知识向量化

# %%
class EmbeddingGenerator:
    def __init__(self, model_name):
        self.model_name = model_name
        self.client = ZhipuAI(api_key=ZHIPUAI_API_KEY)

    def embed_documents(self, texts):
        embeddings = []
        for text in texts:
            response = self.client.embeddings.create(model=self.model_name, input=text)
            if hasattr(response, 'data') and response.data:
                embeddings.append(response.data[0].embedding)
            else:
                # 如果获取嵌入失败，返回一个零向量
                embeddings.append([0] * 1024)  # 假设嵌入向量维度为 1024
        return embeddings


    def embed_query(self, query):
        # 使用相同的处理逻辑，只是这次只为单个查询处理
        response = self.client.embeddings.create(model=self.model_name, input=query)
        if hasattr(response, 'data') and response.data:
            return response.data[0].embedding
        return [0] * 1024  # 如果获取嵌入失败，返回零向量


embedding_generator = EmbeddingGenerator(model_name="embedding-3")

# %%
# 文本列表
texts = [content for document in splits for split_type, content in document if split_type == 'page_content']

# %% [markdown]
# ## 7. 知识入库

# %%
chroma_store = Chroma(
    collection_name="example_collection",
    embedding_function=embedding_generator,  # 使用定义的嵌入生成器实例
    create_collection_if_not_exists=True
)

# %%
# 添加文本到 Chroma VectorStore
IDs = chroma_store.add_texts(texts=texts)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 # 添加文本到 Chroma VectorStore
# ----> 2 IDs = chroma_store.add_texts(texts=texts)
#
# File F:\programe_install\Anaconda3\envs\flaskProjectNew\Lib\site-packages\langchain_chroma\vectorstores.py:360, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     354         self._collection.upsert(
#     355             embeddings=embeddings_without_metadatas,  # type: ignore
#     356             documents=texts_without_metadatas,
#     357             ids=ids_without_metadatas,
#     358         )
#     359 else:
# --> 360     self._collection.upsert(
#     361         embeddings=embeddings,  # type: ignore
#     362         documents=texts,
#     363         ids=ids,
#     364     )
#     365 return ids
#
# File F:\programe_install\Anaconda3\envs\flaskProjectNew\Lib\site-packages\chromadb\api\models\Collection.py:342, in Collection.upsert(self, ids, embeddings, metadatas, documents, images, uris)
#     311 def upsert(
#     312     self,
#     313     ids: OneOrMany[ID],
#    (...)
#     323     uris: Optional[OneOrMany[URI]] = None,
#     324 ) -> None:
#     325     """Update the embeddings, metadatas or documents for provided ids, or create them if they don't exist.
#     326
#     327     Args:
#    (...)
#     334         None
#     335     """
#     336     (
#     337         ids,
#     338         embeddings,
#     339         metadatas,
#     340         documents,
#     341         uris,
# --> 342     ) = self._validate_and_prepare_upsert_request(
#     343         ids, embeddings, metadatas, documents, images, uris
#     344     )
#     346     self._client._upsert(
#     347         collection_id=self.id,
#     348         ids=ids,
#    (...)
#     354         database=self.database,
#     355     )
#
# File F:\programe_install\Anaconda3\envs\flaskProjectNew\Lib\site-packages\chromadb\api\models\CollectionCommon.py:540, in CollectionCommon._validate_and_prepare_upsert_request(self, ids, embeddings, metadatas, documents, images, uris)
#     513 def _validate_and_prepare_upsert_request(
#     514     self,
#     515     ids: OneOrMany[ID],
#    (...)
#     531     Optional[URIs],
#     532 ]:
#     533     (
#     534         ids,
#     535         embeddings,
#     536         metadatas,
#     537         documents,
#     538         images,
#     539         uris,
# --> 540     ) = self._validate_embedding_set(
#     541         ids, embeddings, metadatas, documents, images, uris
#     542     )
#     544     if embeddings is None:
#     545         if documents is not None:
#
# File F:\programe_install\Anaconda3\envs\flaskProjectNew\Lib\site-packages\chromadb\api\models\CollectionCommon.py:174, in CollectionCommon._validate_embedding_set(self, ids, embeddings, metadatas, documents, images, uris, require_embeddings_or_data)
#     152 def _validate_embedding_set(
#     153     self,
#     154     ids: OneOrMany[ID],
#    (...)
#     172     Optional[URIs],
#     173 ]:
# --> 174     valid_ids = validate_ids(maybe_cast_one_to_many_ids(ids))
#     175     valid_embeddings = (
#     176         validate_embeddings(
#     177             self._normalize_embeddings(maybe_cast_one_to_many_embedding(embeddings))
#    (...)
#     180         else None
#     181     )
#     182     valid_metadatas = (
#     183         validate_metadatas(maybe_cast_one_to_many_metadata(metadatas))
#     184         if metadatas is not None
#     185         else None
#     186     )
#
# File F:\programe_install\Anaconda3\envs\flaskProjectNew\Lib\site-packages\chromadb\api\types.py:273, in validate_ids(ids)
#     271     raise ValueError(f"Expected IDs to be a list, got {type(ids).__name__} as IDs")
#     272 if len(ids) == 0:
# --> 273     raise ValueError(f"Expected IDs to be a non-empty list, got {len(ids)} IDs")
#     274 seen = set()
#     275 dups = set()
#
# ValueError: Expected IDs to be a non-empty list, got 0 IDs

# %% [markdown]
# ## 8. 构建检索器

# %%
retriever = chroma_store.as_retriever()

# %% [markdown]
# ## 9.构建调用链路

# %%
prompt = hub.pull("rlm/rag-prompt")
print(prompt)
# Out:
# input_variables=['context', 'question'] metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"))]

# %%
prompt.pretty_print()
# Out:
# ================================ Human Message =================================
#
# You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.
# Question: {question}
# Context: {context}
# Answer:

# %%
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

# %%
rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | chat
    | StrOutputParser()
)

# %% [markdown]
# ## 10. 进行提问

# %%
"""
1. 查询处理：该命令接受查询“什么是任务分解？”并将其传递给 retriever 组件。检索器本质上是系统中的搜索功能，设置为在预先索引的数据集中查找信息 - 这里是根据博客内容创建的矢量存储。
2. 语义搜索：检索器使用向量存储中存储的文本片段的嵌入（向量表示）来执行语义搜索。它将查询的向量表示与存储的片段的向量进行比较，以识别在语义上与查询最相似的片段。
3. 检索相关文本片段：根据相似度分数，检索器从博客中选择并返回与查询最匹配的文本片段。这些片段包含被认为与回答任务分解问题最相关的信息。
"""

rag_res = rag_chain.invoke("cpolar的操作步骤有哪些?")
print(rag_res)
# Out:
# 我不知道cpolar的操作步骤是什么，因为提供的信息中没有相关的内容。如果可以提供更多上下文或详细信息，我可能能够帮助回答这个问题。

# %% [markdown]
# ## 11. 删除数据，从头测试

# %%
chroma_store.delete_collection()
